# %%
from collections import deque
class Stack:
    def __init__(self):
        self.container=deque()
    def push(self,x):
        return self.container.append(x)
    def pop(self):
        return self.container.pop()
    def peek(self):
        return self.container[-1]
    def is_empty(self):
        return len(self.container)==0
    def size(self):
        return len(self.container)
    
#driver code
#create object for Stack class
s=Stack()
# Out:
# the peek element is --- 10
# stack is not empty
# the size of the stack is  2

# %%
#getting the size of the stack
print("the size of the stack is ",s.size())
# Out:
# the size of the stack is  4

# %%
#pushing elements on to the stack
s.push(5)
s.push(10)
s.push(15)

# %%
#poping out the element
s.pop()
# Out:
# 15

# %%
#printing out the elements in stack
while not s.is_empty():
    print(s.pop())

# %%
#getting the last element
if s.is_empty():
    print("stack is already empty")
else:
    print("the peek element is ---",s.peek())
# Out:
# stack is already empty

# %%
#checking if the stack is empty or not
if s.is_empty():
    print("stack is empty")
else:
    print("stack is not empty")
# Out:
# stack is empty

# %%
import pandas as pd
data=pd.read_csv("Annual Price.csv")

# %%
data
# Out:
#          Date  Price
# 0  March 2020    234
# 1  March 2021    345
# 2  March 2022    445
# 3  March 2023    553
# 4  March 2025    678
# 5  March 2026    789
# 6  March 2027    598
# 7  March 2028    569
# 8  March 2029    987

# %%
#convertind data to list
dataList=data.values.tolist()
dataList
#a 2-d list
# Out:
# [['March 2020', 234],
#  ['March 2021', 345],
#  ['March 2022', 445],
#  ['March 2023', 553],
#  ['March 2025', 678],
#  ['March 2026', 789],
#  ['March 2027', 598],
#  ['March 2028', 569],
#  ['March 2029', 987]]

# %%
#To retrieve the price on March 2026,we cant directly access,so loop
for elements in dataList:
    if elements[0]=="March 2026":
        print(elements[1])
#T.c:O(n)
# Out:
# 789

# %%
#converting dataList to hash table using dict keyword
hashing=dict(data.values)
hashing['March 2026']
# Out:
# 789

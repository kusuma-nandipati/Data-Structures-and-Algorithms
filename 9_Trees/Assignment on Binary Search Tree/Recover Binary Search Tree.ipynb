# %% [markdown]
# # Approach-1: using list

# %%
class Node:
    def __init__(self,val):
        self.val=val
        self.left=None
        self.right=None
    def inOrder(self,root,list1):
        if root is None:
            return list1
        list1=self.inOrder(root.left,list1)
        list1.append(root)
        list1=self.inOrder(root.right,list1)
        return list1
    def recoverTree(self,root):
        list1=self.inOrder(root,[])
        n=len(list1)
        
        a=list1[0]
        for i in range(1,n):
            if list1[i].val<list1[i-1].val:
                a=list1[i-1]
                break
        b=list1[n-1]
        for i in range(n-2,-1,-1):
            if list1[i].val>list1[i+1].val:
                b=list1[i+1]
                break
        a.val,b.val=b.val,a.val
    def inOrderP(self,root,list1):
        if root is None:
            return list1
        list1=self.inOrderP(root.left,list1)
        list1.append(root.val)
        list1=self.inOrderP(root.right,list1)
        return list1
#driver code
obj=Node(0)
root=Node(3)
root.left=Node(1)
root.right=Node(4)
root.right.left=Node(2)
obj.recoverTree(root)
print(obj.inOrderP(root,[]))
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # Approach-2:Three Pointer Approach

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def recoverTree(self, root: TreeNode) -> None:
        self.first = None
        self.mid = None
        self.last = None
        self.prev = TreeNode(float('-inf'))

        def inorder(node):
            if not node:
                return
            inorder(node.left)
            if self.prev and self.prev.val > node.val:
                if not self.first:
                    self.first = self.prev
                    self.mid = node
                else:
                    self.last = node
            self.prev = node
            inorder(node.right)

        inorder(root)
        if self.first and self.last:
            self.first.val, self.last.val = self.last.val, self.first.val
        elif self.first and self.mid:
            self.first.val, self.mid.val = self.mid.val, self.first.val


root = TreeNode(3)
root.left = TreeNode(1)
root.right = TreeNode(4)
root.right.left = TreeNode(2)

def print_inorder(node):
    if not node:
        return
    print_inorder(node.left)
    print(node.val, end=" ")
    print_inorder(node.right)

print("Before recovery (inorder):")
print_inorder(root)
print()

Solution().recoverTree(root)

print("After recovery (inorder):")
print_inorder(root)
print()
# Out:
# Before recovery (inorder):
# 1 3 2 4
# After recovery (inorder):
# 1 2 3 4

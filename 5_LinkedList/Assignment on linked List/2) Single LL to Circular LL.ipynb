# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
class LinkedList:
    def __init__(self):
        self.head=None
        
        '''inserting elements to linkedlist'''
    def insertAtBeginning(self,new_Data):
        new_node=Node(new_Data)
        new_node.next=self.head
        self.head=new_node
        '''converting single ll to circular ll'''
    def convertToCLL(self):
        if not self.head:
            print("List is Empty")
            return
        temp=self.head
        while temp.next:
            temp=temp.next
        temp.next=self.head
        '''printing out the list'''
    def printList(self,circular=False):
        temp=self.head
        if circular:
            while True:
                print(str(temp.data)+" ",end=" ")
                temp=temp.next
                if temp==self.head:
                    break
        else:
            while temp:
                print(str(temp.data)+" ",end=" ")
                temp=temp.next
            
            
            
            
            
llist=LinkedList()
llist.insertAtBeginning(50)
llist.insertAtBeginning(40)
llist.insertAtBeginning(30)
llist.insertAtBeginning(20)
llist.insertAtBeginning(10)
print("single linked list -->")
llist.printList()
llist.convertToCLL()
print("\n")
print("converted circular linked list--->")
llist.printList(circular=True)
print()
# Out:
# single linked list -->
# 10  20  30  40  50
#
# converted circular linked list--->
# 10  20  30  40  50

# %%
def load_factor_calculation(n,m):
    load_factor=n/m
    print("the load factor is---",load_factor)

#driver code
m=int(input("enter the number if data points inserted in the hash table--"))
n=int(input("enter the size of the hash table--"))
load_factor_calculation(m,n)
# Out:
# enter the number if data points inserted in the hash table--3
# enter the size of the hash table--10
# the load factor is--- 0.3
